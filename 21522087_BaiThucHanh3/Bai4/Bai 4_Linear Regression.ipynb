# %%
import numpy as np
import pandas as pd
from google.colab import files
import io
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, r2_score
from sklearn import preprocessing
import matplotlib.pyplot as plt
import copy, math
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Linear Regression** - housing dataset

# %%
df = pd.read_csv('housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df = df.dropna()
df = df.drop(columns=['ocean_proximity'])
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
# [20433 rows x 9 columns]

# %%
X = df.iloc[:,:-1].values
print(f'X shape: {X.shape}, type: {type(X)} \n')
X
# Out:
# X shape: (20433, 8), type: <class 'numpy.ndarray'>
# array([[-1.2223e+02,  3.7880e+01,  4.1000e+01, ...,  3.2200e+02,
#          1.2600e+02,  8.3252e+00],
#        [-1.2222e+02,  3.7860e+01,  2.1000e+01, ...,  2.4010e+03,
#          1.1380e+03,  8.3014e+00],
#        [-1.2224e+02,  3.7850e+01,  5.2000e+01, ...,  4.9600e+02,
#          1.7700e+02,  7.2574e+00],
#        ...,
#        [-1.2122e+02,  3.9430e+01,  1.7000e+01, ...,  1.0070e+03,
#          4.3300e+02,  1.7000e+00],
#        [-1.2132e+02,  3.9430e+01,  1.8000e+01, ...,  7.4100e+02,
#          3.4900e+02,  1.8672e+00],
#        [-1.2124e+02,  3.9370e+01,  1.6000e+01, ...,  1.3870e+03,
#          5.3000e+02,  2.3886e+00]])

# %%
y = df['median_house_value'].values
print(f'y shape: {y.shape}, type: {type(y)} \n')
y
# Out:
# y shape: (20433,), type: <class 'numpy.ndarray'>
# array([452600., 358500., 352100., ...,  92300.,  84700.,  89400.])

# %%
scaler_housing = StandardScaler()

# %%
scaler_housing.fit(X)
X_scaled = scaler_housing.transform(X)

print(f'y shape: {X_scaled.shape}, type: {type(X_scaled)} \n')
X_scaled
# Out:
# y shape: (20433, 8), type: <class 'numpy.ndarray'>
# array([[-1.32731375,  1.05171726,  0.98216331, ..., -0.97331952,
#         -0.97683327,  2.34516291],
#        [-1.32232256,  1.04235526, -0.60621017, ...,  0.86133924,
#          1.67037262,  2.33263161],
#        [-1.33230494,  1.03767426,  1.85576873, ..., -0.81976943,
#         -0.84342665,  1.78293943],
#        ...,
#        [-0.82320322,  1.77727236, -0.92388486, ..., -0.36882637,
#         -0.17377773, -1.14317103],
#        [-0.87311515,  1.77727236, -0.84446619, ..., -0.60356386,
#         -0.39350628, -1.05513604],
#        [-0.83318561,  1.74918635, -1.00330353, ..., -0.03348711,
#          0.07995643, -0.78060586]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.33, random_state=42)

# %%
linear_reg_model = LinearRegression()
linear_reg_model.fit(X_train, y_train)

weights = linear_reg_model.coef_
bias = linear_reg_model.intercept_
print(f'best weights: {weights} \nbest bias: {bias}')
# Out:
# best weights: [-84482.72708518 -90031.32308528  15045.48100293 -18882.37580669
#   50028.17358745 -40418.24722368  14324.62358638  76268.79687262]
# best bias: 207247.8682009606

# %%
y_pred = linear_reg_model.predict(X_test)

for i in range(100):
  print(f'Label: {y_test[i]:<10} | Prediction: {y_pred[i]:<10.4f}')
# Out:
# Label: 245800.0   | Prediction: 197402.5866
# Label: 137900.0   | Prediction: 157886.4812
# Label: 218200.0   | Prediction: 203530.7206
# Label: 220800.0   | Prediction: 173710.9116
# Label: 170500.0   | Prediction: 212870.3842
# Label: 75000.0    | Prediction: 108986.3297
# Label: 269400.0   | Prediction: 284528.1070
# Label: 228900.0   | Prediction: 250017.3984
# Label: 500001.0   | Prediction: 390640.7140
# Label: 80800.0    | Prediction: 49676.1297
# Label: 170000.0   | Prediction: -21720.0045
# Label: 87800.0    | Prediction: 126569.8294
# Label: 242200.0   | Prediction: 245885.4028
# Label: 165500.0   | Prediction: 194263.3477
# Label: 164000.0   | Prediction: 62734.4242
# Label: 238000.0   | Prediction: 179195.4794
# Label: 283300.0   | Prediction: 217474.8284
# Label: 249400.0   | Prediction: 283949.3831
# Label: 143600.0   | Prediction: 219600.5682
# Label: 333100.0   | Prediction: 277013.9606
# Label: 164900.0   | Prediction: 231660.7655
# Label: 216100.0   | Prediction: 162372.1187
# Label: 188700.0   | Prediction: 216521.6494
# Label: 59600.0    | Prediction: 83704.9106
# Label: 181400.0   | Prediction: 226582.3894
# Label: 224200.0   | Prediction: 261937.1777
# Label: 238200.0   | Prediction: 261372.5693
# Label: 210300.0   | Prediction: 243276.3049
# Label: 253400.0   | Prediction: 255640.5708
# Label: 85800.0    | Prediction: 108600.7688
# Label: 90900.0    | Prediction: 162894.1005
# Label: 131300.0   | Prediction: 202979.9226
# Label: 209700.0   | Prediction: 196186.9077
# Label: 244800.0   | Prediction: 214392.3150
# Label: 283800.0   | Prediction: 276249.0961
# Label: 400000.0   | Prediction: 483988.5472
# Label: 500001.0   | Prediction: 533305.6122
# Label: 73500.0    | Prediction: 77069.5717
# Label: 169600.0   | Prediction: 165753.8175
# Label: 340300.0   | Prediction: 324078.3609
# Label: 142500.0   | Prediction: 218490.0955
# Label: 71800.0    | Prediction: 67638.6143
# Label: 197200.0   | Prediction: 241004.3875
# Label: 114600.0   | Prediction: 187040.3510
# Label: 350000.0   | Prediction: 186415.9424
# Label: 157000.0   | Prediction: 146882.6001
# Label: 111500.0   | Prediction: 184006.6248
# Label: 500001.0   | Prediction: 360566.1677
# Label: 346200.0   | Prediction: 214200.6885
# Label: 212100.0   | Prediction: 215092.5358
# Label: 177500.0   | Prediction: 203045.8799
# Label: 159600.0   | Prediction: 225745.3034
# Label: 145900.0   | Prediction: 145177.1763
# Label: 176300.0   | Prediction: 215272.9269
# Label: 133700.0   | Prediction: 187236.5992
# Label: 495500.0   | Prediction: 290990.7711
# Label: 213400.0   | Prediction: 212027.1265
# Label: 266300.0   | Prediction: 249698.1694
# Label: 500001.0   | Prediction: 423136.8647
# Label: 67500.0    | Prediction: 45048.3986
# Label: 170900.0   | Prediction: 155557.8982
# Label: 203400.0   | Prediction: 186006.7908
# Label: 66900.0    | Prediction: 10825.5632
# Label: 365900.0   | Prediction: 266823.5575
# Label: 347700.0   | Prediction: 240110.4841
# Label: 422000.0   | Prediction: 332760.8343
# Label: 131300.0   | Prediction: 137979.0577
# Label: 187100.0   | Prediction: 226567.3319
# Label: 200000.0   | Prediction: 196611.6828
# Label: 242800.0   | Prediction: 276903.2018
# Label: 234300.0   | Prediction: 255907.6380
# Label: 269000.0   | Prediction: 335811.0189
# Label: 112500.0   | Prediction: 252608.0970
# Label: 500001.0   | Prediction: 398334.3362
# Label: 199800.0   | Prediction: 193695.6468
# Label: 252600.0   | Prediction: 267997.9366
# Label: 83500.0    | Prediction: 163396.4363
# Label: 323800.0   | Prediction: 299545.2603
# Label: 141000.0   | Prediction: 155308.1577
# Label: 159500.0   | Prediction: 240048.9667
# Label: 477800.0   | Prediction: 387829.9583
# Label: 82800.0    | Prediction: 159761.3817
# Label: 123800.0   | Prediction: 57713.6293
# Label: 340400.0   | Prediction: 372574.5968
# Label: 186200.0   | Prediction: 180201.8180
# Label: 248700.0   | Prediction: 276402.3238
# Label: 188000.0   | Prediction: 199458.2483
# Label: 183000.0   | Prediction: 117784.4065
# Label: 494700.0   | Prediction: 336878.4317
# Label: 308800.0   | Prediction: 258988.4680
# Label: 255400.0   | Prediction: 277019.0243
# Label: 155100.0   | Prediction: 82863.9122
# Label: 103000.0   | Prediction: 77321.3726
# Label: 50500.0    | Prediction: 124863.7886
# Label: 482200.0   | Prediction: 355581.8888
# Label: 50000.0    | Prediction: 55590.0755
# Label: 500001.0   | Prediction: 365865.7220
# Label: 55000.0    | Prediction: 64538.2141
# Label: 204200.0   | Prediction: 199852.2940
# Label: 142000.0   | Prediction: 181384.6426

# %%
# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = mean_squared_error(y_test, y_pred, squared=True)

# R-squared (R²)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R²):", r2)
# Out:
# Mean Absolute Error (MAE): 50476.398238187496
# Mean Squared Error (MSE): 4675459167.725828
# Root Mean Squared Error (RMSE): 4675459167.725828
# R-squared (R²): 0.6473837161332721

# %% [markdown]
# **Compare to Normal Equation** <br>
#
# Mean Absolute Error (MAE): 50476.39823807128 <br>
# Mean Squared Error (MSE): 4675459167.725623 <br>
# Root Mean Squared Error (RMSE): 4675459167.725623 <br>
# R-squared (R²): 0.6473837161332876
